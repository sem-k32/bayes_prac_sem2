# %%
import PIL.Image as Image
import numpy as np
from matplotlib import pyplot as plt

# %%
image = Image.open("../../data/photo_1.jpg")

# %%
image.size
# Out:
# (1280, 720)

# %%
plt.imshow(image.reduce(2));

# %%
np.array(image).shape
# Out:
# (720, 1280, 3)

# %%
image = Image.open("../../data/photo_2.jpg")
plt.imshow(image.reduce(2));

# %%
image.size
# Out:
# (1280, 720)
