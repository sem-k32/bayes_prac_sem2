# %%
import PIL.Image as Image
from PIL import ImageFilter
import numpy as np
from matplotlib import pyplot as plt

# %%
reduce_ratio = 3

# %%
image = Image.open("../../data/photo_0.jpg")
print(image.size)

plt.imshow(image.reduce(reduce_ratio));
print(image.reduce(reduce_ratio).size)
# Out:
# (1280, 720)
# (427, 240)

# %%
image = Image.open("../../data/photo_1.jpg")
plt.imshow(image.reduce(reduce_ratio));
print(image.reduce(reduce_ratio).size)
# Out:
# (427, 240)

# %%
image = Image.open("../../data/photo_2.jpg")
plt.imshow(image.reduce(reduce_ratio));
print(image.reduce(reduce_ratio).size)
# Out:
# (427, 240)

# %%
image = Image.open("../../data/photo_3.jpg")
plt.imshow(image.reduce(reduce_ratio));
print(image.reduce(reduce_ratio).size)
# Out:
# (427, 240)

# %%
image = Image.open("../../data/photo_4.jpg")
image = image.reduce(reduce_ratio)
plt.imshow(image);
print(image.size)
# Out:
# (427, 240)

# %%
print(np.array(image).shape)
# Out:
# (240, 427, 3)
