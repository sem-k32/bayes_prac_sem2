# %%
import PIL.Image as Image
from PIL import ImageFilter
import numpy as np
from matplotlib import pyplot as plt

# %%
image = Image.open("../../data/photo_1.jpg")

# %%
image.size
# Out:
# (1280, 720)

# %%
plt.imshow(image.reduce(3));

# %%
image.reduce(3).size
# Out:
# (427, 240)

# %%
np.array(image).shape
# Out:
# (720, 1280, 3)

# %%
image = Image.open("../../data/photo_2.jpg")
plt.imshow(image.reduce(2).filter(ImageFilter.SHARPEN));

# %%
plt.imshow(image.reduce(3));

# %%
np.array(image.reduce(3)).shape
# Out:
# (240, 427, 3)
