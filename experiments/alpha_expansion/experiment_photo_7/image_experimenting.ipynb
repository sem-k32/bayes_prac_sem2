# %%
import PIL.Image as Image
from PIL import ImageFilter
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.colors import ListedColormap

# %%
image = Image.open("../../../data/archive/Image/7.jpg")
print(image.size)
plt.imshow(image.reduce(4));
print(image.reduce(4).size)
# Out:
# (2000, 1500)
# (500, 375)

# %%
image = Image.open("../../../data/archive/Image/11.jpg")
print(image.size)
plt.imshow(image.reduce(5));
print(image.reduce(5).size)
# Out:
# (2400, 1800)
# (480, 360)

# %%
plt.imshow(np.array(image.reduce(4))[])

# %%
image = Image.open("../../../data/archive/Image/13.jpg")
print(image.size)
plt.imshow(image.reduce(5));
print(image.reduce(5).size)
# Out:
# (2560, 1316)
# (512, 264)

# %%
image = Image.open("../../../data/archive/Image/17.jpg")
print(image.size)
plt.imshow(image.reduce(8));
print(image.reduce(8).size)
# Out:
# (4095, 2505)
# (512, 314)
